# %%
from process_events import process_events
from pathlib import Path

# Define paths
events_file = Path("/home/jovyan/fld/pluvial.csv")
catchments_dir = Path("/home/jovyan/catchments")
cfe_results_dir = Path("/home/jovyan/cfe_results")
output_file = Path("/home/jovyan/pfi_run_output/pluvial_final_withreturnperiod.csv")

# Process events and generate output
results_df = process_events(events_file, catchments_dir, cfe_results_dir, output_file)

# Display results
print(results_df)
# Out:
# [SKIPPED] No alpha1 >= 11.2 found for catchment cat-105032 from 2015-05-30 21:00:00 to 2015-05-31 21:00:00
# Skipping catchment cat-105032 for date 2015-05-31 20:14:00 due to error in select_giuh_timeline
# [SKIPPED] No alpha1 >= 11.2 found for catchment cat-1078916 from 2010-07-23 06:00:00 to 2010-07-24 06:00:00
# Skipping catchment cat-1078916 for date 2010-07-24 05:15:00 due to error in select_giuh_timeline
# [SKIPPED] File not found for catchment cat-1079314
# Skipping catchment cat-1079314 for date 2013-04-17 22:45:00 due to error in select_giuh_timeline
# [SKIPPED] File not found for catchment cat-1079314
# Skipping catchment cat-1079314 for date 2013-04-18 20:00:00 due to error in select_giuh_timeline
# [SKIPPED] File not found for catchment cat-1079314
# Skipping catchment cat-1079314 for date 2017-10-14 19:31:00 due to error in select_giuh_timeline
# ...
